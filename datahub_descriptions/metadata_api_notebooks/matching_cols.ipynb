# %% [markdown]
# # Notebook to match the mismatched columns
#
# Find details on mismatched columns on Confluence:
# https://rystadenergy.atlassian.net/wiki/spaces/LP/pages/1575747640/Missing+Column+Descriptions
#
# Note: to use this NB, you may need to move it into datahub_descriptions.

# %% [markdown]
# Let's start by getting the column descriptions.

# %%
from modules.scrape_tables import TableScraperDC
from modules.populate_descriptions import CustomDescriptionsDC
import pandas as pd
import logging
import configparser

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

config = configparser.ConfigParser()
config.read('src/config.conf')
# Out:
# ['src/config.conf']

# %%
def get_column_descriptions():
    # Set pdf path location to the desired pdf file, in this case the UCube structure
    pdf_path = config['FILES']['pdf_path']
    xlsx_path = config['FILES']['xlsx_path']
    scraper = TableScraperDC(pdf_path=pdf_path, xlsx_path=xlsx_path)
    
    formatted_tables = scraper.extract_tables_from_xlsx(xlsx_path=xlsx_path)
    logging.info("Number of tables extracted: %s.", len(formatted_tables.keys()))

    if formatted_tables:
        logging.info("Formatted tables are ready for use.")
        return formatted_tables
    else:
        logging.info("No tables were extracted or formatted.")
        return{}

# %%
column_desc_tables = get_column_descriptions()
# Out:
# 2024-02-15 15:04:54,949 - INFO - TableScraperDC initialized
# 2024-02-15 15:04:54,951 - INFO - Starting table extraction from XLSX: /home/rin/code/llm_proj/datahub_dev/Skuld-LLM/datahub_descriptions/src/UCube structure.xlsx
# 2024-02-15 15:04:55,014 - INFO - Starting to capture tables...
# 2024-02-15 15:04:55,015 - INFO - Processing new table: Asset
# 2024-02-15 15:04:55,016 - INFO - Starting to capture tables...
# 2024-02-15 15:04:55,017 - INFO - Finished processing table: Asset
# 2024-02-15 15:04:55,018 - INFO - Processing new table: AssetCompany
# 2024-02-15 15:04:55,019 - INFO - Finished processing table: AssetCompany
# 2024-02-15 15:04:55,019 - INFO - Processing new table: AssetLifeCycle
# 2024-02-15 15:04:55,021 - INFO - Finished processing table: AssetLifeCycle
# 2024-02-15 15:04:55,022 - INFO - Processing new table: BreakevenPrices
# 2024-02-15 15:04:55,023 - INFO - Finished processing table: BreakevenPrices
# 2024-02-15 15:04:55,023 - INFO - Processing new table: Company
# 2024-02-15 15:04:55,025 - INFO - Finished processing table: Company
# 2024-02-15 15:04:55,026 - INFO - Processing new table: DataQuality
# 2024-02-15 15:04:55,027 - INFO - Finished processing table: DataQuality
# 2024-02-15 15:04:55,027 - INFO - Processing new table: EconomicsType
# 2024-02-15 15:04:55,028 - INFO - Finished processing table: EconomicsType
# 2024-02-15 15:04:55,028 - INFO - Processing new table: Geography
# 2024-02-15 15:04:55,029 - INFO - Finished processing table: Geography
# 2024-02-15 15:04:55,030 - INFO - Processing new table: HistoricCompany
# 2024-02-15 15:04:55,032 - INFO - Finished processing table: HistoricCompany
# 2024-02-15 15:04:55,033 - INFO - Processing new table: LifeCycle
# 2024-02-15 15:04:55,034 - INFO - Finished processing table: LifeCycle
# 2024-02-15 15:04:55,035 - INFO - Processing new table: LifeCycleTS
# 2024-02-15 15:04:55,036 - INFO - Finished processing table: LifeCycleTS
# 2024-02-15 15:04:55,037 - INFO - Processing new table: OilAndGas
# 2024-02-15 15:04:55,038 - INFO - Finished processing table: OilAndGas
# 2024-02-15 15:04:55,038 - INFO - Processing new table: OilAndGasType
# 2024-02-15 15:04:55,039 - INFO - Finished processing table: OilAndGasType
# 2024-02-15 15:04:55,040 - INFO - Processing new table: OtherParameter
# 2024-02-15 15:04:55,041 - INFO - Finished processing table: OtherParameter
# 2024-02-15 15:04:55,041 - INFO - Processing new table: Reserves
# 2024-02-15 15:04:55,042 - INFO - Finished processing table: Reserves
# 2024-02-15 15:04:55,043 - INFO - Processing new table: Prices
# 2024-02-15 15:04:55,044 - INFO - Finished processing table: Prices
# 2024-02-15 15:04:55,045 - INFO - Processing new table: Economics
# 2024-02-15 15:04:55,047 - INFO - Finished processing table: Economics
# 2024-02-15 15:04:55,047 - INFO - Processing new table: EconomicsPV
# 2024-02-15 15:04:55,049 - INFO - Finished processing table: EconomicsPV
# 2024-02-15 15:04:55,050 - INFO - Processing new table: NPV
# 2024-02-15 15:04:55,051 - INFO - Finished processing table: NPV
# 2024-02-15 15:04:55,053 - INFO - Processing new table: Production
# 2024-02-15 15:04:55,062 - INFO - Finished processing table: Production
# 2024-02-15 15:04:55,063 - INFO - Processing new table: Resources
# 2024-02-15 15:04:55,066 - INFO - Finished processing table: Resources
# 2024-02-15 15:04:55,069 - INFO - Processing new table: WellLifeCycle
# 2024-02-15 15:04:55,072 - INFO - Finished processing table: WellLifeCycle
# 2024-02-15 15:04:55,074 - INFO - Processing new table: DiscoveredResources
# 2024-02-15 15:04:55,076 - INFO - Finished processing table: DiscoveredResources
# 2024-02-15 15:04:55,078 - INFO - Number of tables extracted: 23.
# 2024-02-15 15:04:55,080 - INFO - Formatted tables are ready for use.

# %% [markdown]
# ## Case 1 - mismatched capitalizations
#
# In this case we take the table vDataFeed_UCube_AssetCompany. It has a column in MSSQL called FK_owner, but in the description tables it is FK_Owner.
#
# After the initial ingestion, the description for FK_Owner is already there. To match it to the name of the column in MSSQL (which is the same as what appears in the UI), we will take the full GET response and analyze it, to establish the matching.

# %%
# Set the environment variables we need
base_url = config['DATAHUB']['base_url'] # Location of DataHub
gms_server = config['DATAHUB']['gms_server']
token = config['DATAHUB']['token']
env = 'DEV'

urn = 'urn:li:dataset:(urn:li:dataPlatform:mssql,ekofisk.RECubeDataRelease.dbo.vDataFeed_UCube_AssetCompany,DEV)'

# %%
# GET ENTITY

import requests
from urllib.parse import quote

# Endpoint for GET request
endpoint = f'/openapi/entities/v1/latest?urns={quote(urn)}'

url = f"{gms_server}{endpoint}"

headers = {
    "Authorization": f"Bearer {token}",
    "Content-Type": "application/json"
}

response = requests.get(
    url=url,
    headers=headers
)

# %%
response_dict = response.json()

# Column descriptions
column_desc = response_dict['responses'][urn]['aspects']['editableSchemaMetadata']['value']['editableSchemaFieldInfo']

# Column types
column_types = response_dict['responses'][urn]['aspects']['schemaMetadata']['value']['fields']

# %%
column_desc
# Out:
# [{'fieldPath': 'Id',
#   'description': 'Links to FK_AssetCompany in other tables'},
#  {'fieldPath': 'FK_Owner',
#   'description': 'Links to FK_Company  in other tables'},
#  {'fieldPath': 'FK_Asset', 'description': 'Links to FK_Asset in other tables'},
#  {'fieldPath': 'Asset Share',
#   'description': 'Asset Share splits all asset data onto the individual shares of the owners according to their working interest, so that these asset shares can be treated independent of the Asset and Company dimensions. The asset-share memberss are named "Asset"-"Company"._x000D__x000D_'},
#  {'fieldPath': 'NOC in homecountry',
#   'description': 'The NOC in Homecountry variable is "NOC at home" for a NOC in its home country where it has priviligies, otherwise "Other companies".'},
#  {'fieldPath': 'Operator Non-operator',
#   'description': 'Operator - Non-operator splits the production (or Economics) into the share of the operators and the share of the non-operating owners. Use Operator-Non-operator e.g. to see for a selected company how large part of its portfolio it operates.'}]

# %%
# Extract fieldPath values and lowercase them for comparison
desc_field_paths = {d['fieldPath'].lower(): d['fieldPath'] for d in column_desc}
type_field_paths = {t['fieldPath'].lower(): t['fieldPath'] for t in column_types}

# Find common fieldPath values (case-insensitive) using sets
common_field_paths_lower = set(desc_field_paths.keys()) & set(type_field_paths.keys())

# Filter out exact matches and identifying mismatches (case-sensitive)
exact_matches = []
mismatches = []

for common_lower in common_field_paths_lower:
    desc_original = desc_field_paths[common_lower]
    type_original = type_field_paths[common_lower]
    if desc_original == type_original:
        # Means that capitalization is the same and we are good to move on
        exact_matches.append(desc_original)
    else:
        # There is a mismatch between the capitalizations, so we will have to append the description column
        mismatches.append((desc_original, type_original))

exact_matches, mismatches
# Out:
# (['Asset Share',
#   'NOC in homecountry',
#   'Operator Non-operator',
#   'Id',
#   'FK_Asset'],
#  [('FK_Owner', 'FK_owner')])

# %%
mismatches
# Out:
# [('FK_Owner', 'FK_owner')]

# %%
# PUSH DESCRIPTIONS TO DATAHUB
# Note that this is for only one column and needs to be reworked for multiple

desc_original = mismatches[0][0] #the capitalization from the xlsx, which we need to use to get the description
type_original = mismatches[0][1] #the correct capitalization as ingested into DataHub

# desc_original = 'FK_Owner'
# type_original = 'FK_owner'

# Call the metadata emitter
metadata_emitter = CustomDescriptionsDC(tables_dict={}, env=env, gms_server=gms_server, token=token)

# Set up the dictionary to be pushed - remember that this needs to be complete! We can't just push the individual column, we have to push the rest too.
# So we will grab them from column_desc and then modify
column_description_dict = {item['fieldPath']: item['description'] for item in column_desc}

# Replace the key 'FK_Owner' with 'FK_owner' in the transformed dictionary
if desc_original in column_description_dict:
    column_description_dict[type_original] = column_description_dict.pop(desc_original)

# Emit the metadata
metadata_emitter.column_desc_emitter(gms_server=gms_server, token=token, urn=urn, column_dict=column_description_dict)
# Out:
# 2024-02-15 15:06:04,202 - INFO - CustomDescriptionsDC initialized for environment: DEV
# 2024-02-15 15:06:04,205 - INFO - Emitting column descriptions for URN: urn:li:dataset:(urn:li:dataPlatform:mssql,ekofisk.RECubeDataRelease.dbo.vDataFeed_UCube_AssetCompany,DEV)
# 2024-02-15 15:06:04,235 - INFO - Successfully emitted column description metadata.

# %% [markdown]
# ## Case 2 - Abbreviations vol. 1
#
# Some tables have been abbreviated in MSSQL.
#
# For example, we see 'NPVCurrentYearLLLC' in DataHub but in the XLSX table we have 'NPV Current Year Low Low Low Case'. We have to match these columns.
#
# This kind of abbreviation is for the case for the NPV and Production tables.

# %%
# We have our descriptions for each column in the tables. Let's take NPV as an example.
column_desc_tables['Production']
# Out:
#                               column_name  \
# 0                                      Id
# 1                                Fk_Asset
# 2                       FK_OtherParameter
# 3                              FK_Company
# 4                            FK_OilAndGas
# 5                      FK_HistoricCompany
# 6                          FK_DataQuality
# 7                          FK_LifeCycleTS
# 8                            FK_LifeCycle
# 9                        FK_OilAndGasType
# 10          NPV Current Year Forward Case
# 11             NPV Current Year High Case
# 12              NPV Current Year Low Case
# 13                       NPV Current Year
# 14              NPV Current Year Mid Case
# 15          NPV Current Year Low Low Case
# 16          NPV Current Year Mid Low Case
# 17      NPV Current Year Low Low Low Case
# 18      NPV Current Year Mid Low Low Case
# 19      NPV Current Year Mid Mid Low Case
# 20  NPV Current Year Mid Mid Low Low Case
# 21                       FK_WellLifeCycle
#
#                                           description
# 0                   all tables have Id as Primary Key
# 1                 Links to FK_Asset from other tables
# 2        Links to FK_OtherParameter from other tables
# 3               Links to FK_Company from other tables
# 4             Links to FK_OilAndGas from other tables
# 5       Links to FK_HistoricCompany from other tables
# 6           Links to FK_DataQuality from other tables
# 7           Links to FK_LifeCycleTS from other tables
# 8             Links to FK_LifeCycle from other tables
# 9       Links to FK_EOilAndGasTypee from other tables
# 10  NPV Current Year Forward Case is a "short cut"...
# 11        NPV Current Year at 120 dollar brent price.
# 12         NPV Current Year at 40 dollar brent price.
# 13  NPV Current Year is a "short cut" value item, ...
# 14        NPV Current Year at 100 dollar brent price.
# 15         NPV Current Year at 30 dollar brent price.
# 16         NPV Current Year at 70 dollar brent price.
# 17         NPV Current Year at 20 dollar brent price.
# 18         NPV Current Year at 50 dollar brent price.
# 19         NPV Current Year at 80 dollar brent price.
# 20         NPV Current Year at 60 dollar brent price.
# 21        Links to FK_WellLifeCycle from other tables

# %%
# Set the environment variables we need

# LOCAL
base_url = config['DATAHUB']['base_url'] # Location of DataHub
gms_server = config['DATAHUB']['gms_server']
token = config['DATAHUB']['token']
env = 'DEV'

urn = 'urn:li:dataset:(urn:li:dataPlatform:mssql,ekofisk.RECubeDataRelease.dbo.vDataFeed_UCube_Production,DEV)'

# %%
# Start by getting the entities as before

import requests
from urllib.parse import quote

# Endpoint for GET request
endpoint = f'/openapi/entities/v1/latest?urns={quote(urn)}'

url = f"{gms_server}{endpoint}"

headers = {
    "Authorization": f"Bearer {token}",
    "Content-Type": "application/json"
}

response = requests.get(
    url=url,
    headers=headers
)

response_dict = response.json()

# Column descriptions
column_desc = response_dict['responses'][urn]['aspects']['editableSchemaMetadata']['value']['editableSchemaFieldInfo']
# Column types
column_types = response_dict['responses'][urn]['aspects']['schemaMetadata']['value']['fields']

# %%
column_types
# Out:
# [{'fieldPath': 'Id',
#   'nullable': False,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'BIGINT()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'FK_Asset',
#   'nullable': True,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'BIGINT()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'Year',
#   'nullable': False,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'SMALLINT()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'FK_Company',
#   'nullable': True,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'BIGINT()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'FK_OilAndGas',
#   'nullable': True,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'BIGINT()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'FK_DataQuality',
#   'nullable': True,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'BIGINT()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'FK_OtherParameter',
#   'nullable': True,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'BIGINT()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'FK_HistoricCompany',
#   'nullable': True,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'BIGINT()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'FK_LifeCycleTS',
#   'nullable': True,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'BIGINT()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'FK_LifeCycle',
#   'nullable': True,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'BIGINT()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'FK_OilAndGasType',
#   'nullable': True,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'BIGINT()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'Production',
#   'nullable': True,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'REAL()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'Production Forward Case',
#   'nullable': True,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'REAL()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'Production High Case',
#   'nullable': True,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'REAL()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'Production Low Case',
#   'nullable': True,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'REAL()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'Production Mid Case',
#   'nullable': True,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'REAL()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'Production Low Low Case',
#   'nullable': True,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'REAL()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'Production Mid Low Case',
#   'nullable': True,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'REAL()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'ProductionLLLC',
#   'nullable': True,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'REAL()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'ProductionMLLC',
#   'nullable': True,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'REAL()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'ProductionMMLC',
#   'nullable': True,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'REAL()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'ProductionMMLLC',
#   'nullable': True,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'REAL()',
#   'recursive': False,
#   'isPartOfKey': False},
#  {'fieldPath': 'FK_WellLifeCycle',
#   'nullable': True,
#   'type': {'type': {'__type': 'NumberType'}},
#   'nativeDataType': 'BIGINT()',
#   'recursive': False,
#   'isPartOfKey': False}]

# %%
# Function to correct the abbreviations

def correct_field_name(field_name):
    parts = field_name.split()  # Split the field name into parts
    corrected_parts = []
    for part in parts:
        if part == 'Low' or part == 'Mid' or part == 'Case':
            corrected_parts.append(part[0])  # Keep only the first letter of Low, Mid and Case
        else:
            corrected_parts.append(part)  # Keep the other parts
    corrected_name = ''.join(corrected_parts)  # Join the parts without spaces
    return corrected_name

# %%
# Get existing column names from DataHub
existing_column_names = {item['fieldPath'] for item in column_types}

# %%
# Iterate over column_desc and correct the `fieldPath` values if they do not exist in column_types
for field in column_desc:
    if field['fieldPath'] not in existing_column_names:
        corrected_field_path = correct_field_name(field['fieldPath'])
        # Update fieldPath in column_desc with the corrected name
        field['fieldPath'] = corrected_field_path

# %%
column_desc
# Out:
# [{'fieldPath': 'Id', 'description': 'all tables have Id as Primary Key'},
#  {'fieldPath': 'FK_Asset',
#   'description': 'Links to FK_Asset from other tables'},
#  {'fieldPath': 'Year', 'description': 'Year'},
#  {'fieldPath': 'FK_Company',
#   'description': 'Links to FK_Company from other tables'},
#  {'fieldPath': 'FK_OilAndGas',
#   'description': 'Links to FK_OilAndGas from other tables'},
#  {'fieldPath': 'FK_DataQuality',
#   'description': 'Links to FK_DataQuality from other tables'},
#  {'fieldPath': 'FK_OtherParameter',
#   'description': 'Links to FK_OtherParameter from other tables'},
#  {'fieldPath': 'FK_HistoricCompany',
#   'description': 'Links to FK_HistoricCompany from other tables'},
#  {'fieldPath': 'FK_LifeCycleTS',
#   'description': 'Links to FK_LifeCycleTS from other tables'},
#  {'fieldPath': 'FK_LifeCycle',
#   'description': 'Links to FK_LifeCycle from other tables'},
#  {'fieldPath': 'FK_OilAndGasType',
#   'description': 'Links to FK_EOilAndGasTypee from other tables'},
#  {'fieldPath': 'Production',
#   'description': 'Production is the expected, annualized rate of extraction of hydrocarbons. Production rates can be expressed in predefined units of energy content, e.g. MMBoe or bcfe (1 MMboe = 6 bcfe), or by customized units as specified by the user. In UCube "bbls" is to be understood as "barrels for liquids, boe for gas".'},
#  {'fieldPath': 'Production Forward Case',
#   'description': 'Production Forward Case is the expected production of hydrocarbon streams assuming using the forward price as price deck. The forward curve is as of the day of UCube release.  Use Oil and Gas Type hierarchy split items as Filter to disaggregate Production into individual hydrocarbon streams.'},
#  {'fieldPath': 'Production High Case',
#   'description': 'Production at 120 dollar brent price.'},
#  {'fieldPath': 'Production Low Case',
#   'description': 'Production at 40 dollar brent price.'},
#  {'fieldPath': 'Production Mid Case',
#   'description': 'Production at 100 dollar brent price.'},
#  {'fieldPath': 'Production Low Low Case',
#   'description': 'Production at 30 dollar brent price.'},
#  {'fieldPath': 'Production Mid Low Case',
#   'description': 'Production at 70 dollar brent price.'},
#  {'fieldPath': 'ProductionLLLC',
#   'description': 'Production at 20 dollar brent price.'},
#  {'fieldPath': 'ProductionMLLC',
#   'description': 'Production at 50 dollar brent price.'},
#  {'fieldPath': 'ProductionMMLC',
#   'description': 'Production at 80 dollar brent price.'},
#  {'fieldPath': 'ProductionMMLLC',
#   'description': 'Production at 60 dollar brent price.'},
#  {'fieldPath': 'FK_WellLifeCycle',
#   'description': 'Links to FK_WellLifeCycle from other tables'}]

# %%
# Call the metadata emitter
metadata_emitter = CustomDescriptionsDC(tables_dict={}, env=env, gms_server=gms_server, token=token)

# Create dictionary based on the list column_desc
column_description_dict = {item['fieldPath']: item['description'] for item in column_desc}

# Emit the metadata
metadata_emitter.column_desc_emitter(gms_server=gms_server, token=token, urn=urn, column_dict=column_description_dict)
# Out:
# 2024-02-15 15:08:38,989 - INFO - CustomDescriptionsDC initialized for environment: DEV
# 2024-02-15 15:08:38,990 - INFO - Emitting column descriptions for URN: urn:li:dataset:(urn:li:dataPlatform:mssql,ekofisk.RECubeDataRelease.dbo.vDataFeed_UCube_Production,DEV)
# 2024-02-15 15:08:39,017 - INFO - Successfully emitted column description metadata.

# %% [markdown]
# # Case 3 - Abbreviations vol. 2
#
# Another abbreviation is for the case of the Prices tables. Here we have 'OilLLLC' in MSSQL and '
# Brent Oil price Low Low Low Case' in the XLSX files. So we need to drop the words Brent and price and then apply the function as above.
#
# The other case for this table is that 'GasLLLC' stands for 'Henry Hub Gas price Low Low Low Case'. So we need to drop Henry Hub and price.

# %%
column_desc_tables['Prices']
# Out:
#                                  column_name  \
# 0                                         Id
# 1                            Brent oil price
# 2                        East Asia LNG price
# 3               Europe Continental gas price
# 4           Henry Hub Gas price Forward Case
# 5              Henry Hub Gas price High Case
# 6               Henry Hub Gas price Low Case
# 7               Henry Hub Gas price Mid Case
# 8                               UK gas price
# 9                        Henry Hub gas price
# 10              Brent Oil price Forward Case
# 11                 Brent Oil price High Case
# 12                  Brent Oil price Low Case
# 13                  Brent Oil price Mid Case
# 14                     WTI Cushing oil price
# 15                                      Year
# 16              Brent Oil price Low Low Case
# 17              Brent Oil price Mid Low Case
# 18          Brent Oil price Low Low Low Case
# 19          Brent Oil price Mid Low Low Case
# 20          Brent Oil price Mid Mid Low Case
# 21      Brent Oil price Mid Mid Low Low Case
# 22      Henry Hub Gas price Low Low Low Case
# 23      Henry Hub Gas price Mid Low Low Case
# 24      Henry Hub Gas price Mid Mid Low Case
# 25  Henry Hub Gas price Mid Mid Low Low Case
# 26                                       CPI
#
#                                           description
# 0                  Links to FK_Prices in other tables
# 1   The Brent oil price is applied for all assest ...
# 2   East Asian LNG: this price is a combination of...
# 3   European continental: historic (prior to 2017)...
# 4   Gas price Forward Case is the market gas price...
# 5   Gas price High Case (120 USD/boe) is the marke...
# 6   Gas price High Case (50 USD/boe) is the market...
# 7   Gas Price Mid Case (100 USD/boe) is the refere...
# 8   United Kingdom: historical gas prices correspo...
# 9   Henry Hub gas price, historical, and future no...
# 10  Oil Price Forward Case is the reference price ...
# 11  Oil Price High Case (120 USD/bbl) is the refer...
# 12  Oil Price Low Case (50 USD/bbl) is the referen...
# 13  Oil Price Mid Case (100 USD/bbl) is the refere...
# 14  The WTI oil price is applied for all Canadian ...
# 15                                               Year
# 16  Oil Price Low Low Case (30 USD/bbl) is the ref...
# 17  Oil Price Mid Low Case (70 USD/bbl) is the ref...
# 18  Brent Oil price Low Low Low Case is oil price ...
# 19  Brent Oil price Mid Low Low Case is oil price ...
# 20  Brent Oil price Mid Mid Low Case is oil price ...
# 21  Brent Oil price Mid Mid Low Low Case is oil pr...
# 22  Oil Price Low Low Low Case (20 USD/bbl) is the...
# 23  Oil Price Mid Low Low Case (50 USD/bbl) is the...
# 24  Oil Price Mid Mid Low Case (80 USD/bbl) is the...
# 25  Oil Price Mid Mid Low Low Case (60 USD/bbl) is...
# 26  Consumer price index shows both the historical...

# %%
# Set the environment variables we need

# LOCAL
base_url = config['DATAHUB']['base_url'] # Location of DataHub
gms_server = config['DATAHUB']['gms_server']
token = config['DATAHUB']['token']
env = 'DEV'

# # DEPLOYMENT
# base_url = 'http://10.10.55.28:9002'
# gms_server = 'http://10.10.55.28:8080'
# token = "TOKEN"
# env = 'DEV'

urn = 'urn:li:dataset:(urn:li:dataPlatform:mssql,ekofisk.RECubeDataRelease.dbo.vDataFeed_UCube_Prices,DEV)'

# %%
# Start by getting the entities as before

import requests
from urllib.parse import quote

# Endpoint for GET request
endpoint = f'/openapi/entities/v1/latest?urns={quote(urn)}'

url = f"{gms_server}{endpoint}"

headers = {
    "Authorization": f"Bearer {token}",
    "Content-Type": "application/json"
}

response = requests.get(
    url=url,
    headers=headers
)

response_dict = response.json()

# Column descriptions
column_desc = response_dict['responses'][urn]['aspects']['editableSchemaMetadata']['value']['editableSchemaFieldInfo']
# Column types
column_types = response_dict['responses'][urn]['aspects']['schemaMetadata']['value']['fields']

# %%
# Get existing column names from DataHub
existing_column_names = {item['fieldPath'] for item in column_types}

# %%
existing_column_names
# Out:
# {'Brent Oil price Forward Case',
#  'Brent Oil price High Case',
#  'Brent Oil price Low Case',
#  'Brent Oil price Low Low Case',
#  'Brent Oil price Mid Case',
#  'Brent Oil price Mid Low Case',
#  'Brent oil price',
#  'CPI',
#  'East Asia LNG price',
#  'Europe Continental gas price',
#  'GasLLLC',
#  'GasMLLC',
#  'GasMMLC',
#  'GasMMLLC',
#  'Henry Hub Gas price Forward Case',
#  'Henry Hub Gas price High Case',
#  'Henry Hub Gas price Low Case',
#  'Henry Hub Gas price Mid Case',
#  'Henry Hub gas price',
#  'Id',
#  'OilLLLC',
#  'OilMLLC',
#  'OilMMLC',
#  'OilMMLLC',
#  'UK gas price',
#  'WTI Cushing oil price',
#  'Year'}

# %%
# Function to correct the abbreviations

# Define the list of allowed keywords
allowed_keywords = ['Oil', 'Gas', 'Low', 'Mid', 'Case']

def correct_field_name(field_name):
    parts = field_name.split()  # Split the field name into parts
     # Keep only the parts that are in the list of allowed keywords
    filtered_parts = [part for part in parts if part in allowed_keywords]

    corrected_parts = []
    for part in filtered_parts:
        if part == 'Low' or part == 'Mid' or part == 'Case':
            corrected_parts.append(part[0])  # Keep only the first letter of Low, Mid and Case
        else:
            corrected_parts.append(part)  # Keep the other parts
    corrected_name = ''.join(corrected_parts)  # Join the parts without spaces
    return corrected_name

# %%
# Iterate over column_desc and correct the `fieldPath` values if they do not exist in column_types
for field in column_desc:
    if field['fieldPath'] not in existing_column_names:
        corrected_field_path = correct_field_name(field['fieldPath'])
        # Update fieldPath in column_desc with the corrected name
        field['fieldPath'] = corrected_field_path

# %%
column_desc
# Out:
# [{'fieldPath': 'Id', 'description': 'Links to FK_Prices in other tables'},
#  {'fieldPath': 'Brent oil price',
#   'description': 'The Brent oil price is applied for all assest outside North America. At asset level price discounts are made for different oil qualities (API, sulphur, total acid), and geographies. The oil price determines the economy, and when production is cut-off.'},
#  {'fieldPath': 'East Asia LNG price',
#   'description': 'East Asian LNG: this price is a combination of both spot and long-term contracts. Historical prices are based on company reported average realized prices. For the future, Rystad Energy assesses East Asian spot LNG using in-house forecasts of global LNG supply and demand. We calculate long term oil-linked contract prices using our Brent crude price forecasts. '},
#  {'fieldPath': 'Europe Continental gas price',
#   'description': 'European continental: historic (prior to 2017) gas prices for the European continental market correspond to German border prices (average import prices reported by BAFA). From 2017 the European continental prices correspond to TTF. The forecast is based on the long-term supply and demand of natural gas.'},
#  {'fieldPath': 'Henry Hub Gas price Forward Case',
#   'description': 'Gas price Forward Case is the market gas price in the Forward Case scenario. The gas price corresponds to Nymex HH price and is used as reference in North America. The price strip is based on the forward market of the day of the UCbe release. For other regions the gas price is considered linked to the reference oil price, i.e. gas price [USD/mcf]=Oil price/factor, where the factor is different in the various regional natural gas markets. This factor also varies with time. At asset level, the gas price differs from the regional reference depending on price regulations, gas sales contracts and access to the regional market.'},
#  {'fieldPath': 'Henry Hub Gas price High Case',
#   'description': 'Gas price High Case (120 USD/boe) is the market gas price in the High Case scenario.\nThe gas price corresponds to Nymex HH price and is used as reference in North America. For other regions the gas price is considered linked to the reference oil price, i.e. gas price [USD/mcf]=Oil price/factor, where the factor is different in the various regional natural gas markets. This factor also varies with time.At asset level the gas price differs from the regional reference depending on price regulations, gas sales contracts and access to the regional market.'},
#  {'fieldPath': 'Henry Hub Gas price Low Case',
#   'description': 'Gas price High Case (50 USD/boe) is the market gas price in the High Case scenario. The gas price corresponds to Nymex HH price and is used as reference in North America. For other regions the gas price is considered linked to the reference oil price, i.e. gas price [USD/mcf]=Oil price/factor, where the factor is different in the various regional natural gas markets. This factor also varies over time. At asset level, the gas price differs from the regional reference depending on price regulations, gas sales contracts, and access to the regional market.'},
#  {'fieldPath': 'Henry Hub Gas price Mid Case',
#   'description': 'Gas Price Mid Case (100 USD/boe) is the reference price in the Mid Case scenario. The gas price corresponds to Nymex HH price and is used as reference in North America. For other regions the gas price is considered linked to the reference oil price, i.e. gas price [USD/mcf]=Oil price/factor, where the factor is different in the various regional natural gas markets. This factor also varies over time. At asset level, the gas price differs from the regional reference depending on price regulations, gas sales contracts, and access to the regional market.'},
#  {'fieldPath': 'UK gas price',
#   'description': "United Kingdom: historical gas prices correspond to NBP (National Balancing Point - a virtual trading location for the sale, purchase and exchange of UK natural gas) prices. For the future, the market's gas price is forecasted based on the long term global supply and demand."},
#  {'fieldPath': 'Henry Hub gas price',
#   'description': 'Henry Hub gas price, historical, and future nominal prices currently achieved on the derivative markets. The Henry Hub price is used as reference in North America. For other regions the gas price is considered oil linked, i.e. gas price [USD/mcf]=Oil price/factor, where the factor is different in the various regional natural gas markets. The factor also varies with time. At asset level the gas price differs from the regional reference depending on price regulations, gas sales contracts and access to the regional market.'},
#  {'fieldPath': 'Brent Oil price Forward Case',
#   'description': 'Oil Price Forward Case is the reference price in the Forward Case scenario._x000D_\nThe reference price corresponds to the Brent oil price in the base case. Fields in North America will apply a WTI or WCS equivalent based on the expected spread to Brent. Lower oil quality will also reduce field level oil price.'},
#  {'fieldPath': 'Brent Oil price High Case',
#   'description': 'Oil Price High Case (120 USD/bbl) is the reference price in the High Case scenario.\nThe reference price corresponds to the Brent oil price in the base case. Fields in North America will apply a WTI or WCS equivalent based on the expected spread to Brent. Lower oil quality will also reduce field level oil price. \nThe reference price is flat in real terms. It reaches it\'s scenario value (120 USD/bbl) "next year", and is is inflated 2.5% following years.'},
#  {'fieldPath': 'Brent Oil price Low Case',
#   'description': 'Oil Price Low Case (50 USD/bbl) is the reference price in the Low Case scenario._x000D_\nThe reference price corresponds to the Brent oil price in the base case. Fields in North America will apply a WTI or WCS equivalent based on the expected spread to Brent. Lower oil quality will also reduce field level oil price._x000D_ The reference price is flat in real terms. It reaches it\'s scenario value (50 USD/bbl) "next year", and is is inflated 2.5% following years.'},
#  {'fieldPath': 'Brent Oil price Mid Case',
#   'description': 'Oil Price Mid Case (100 USD/bbl) is the reference price in the Mid Case scenario. The reference price corresponds to the Brent oil price in the base case. Fields in North America will apply a WTI or WCS equivalent based on the expected spread to Brent. Lower oil quality will also reduce field level oil price. _x000D_The reference price is flat in real terms. It reaches it\'s scenario value (100 USD/bbl) "next year", and is is inflated 2.5% following years.'},
#  {'fieldPath': 'WTI Cushing oil price',
#   'description': 'The WTI oil price is applied for all Canadian onshore assets and United States assets located in the Rocky Mountain, Midwest or Midcontinent province.'},
#  {'fieldPath': 'Year', 'description': 'Year'},
#  {'fieldPath': 'Brent Oil price Low Low Case',
#   'description': 'Oil Price Low Low Case (30 USD/bbl) is the reference price in the Low Low Case scenario.\nThe reference price corresponds to the Brent oil price in the base case. Fields in North America will apply a WTI or WCS equivalent based on the expected spread to Brent. Lower oil quality will also reduce field level oil price. \nThe reference price is flat in real terms. It reaches it\'s scenario value (30 USD/bbl) "next year", and is is inflated 2.5% following years.'},
#  {'fieldPath': 'Brent Oil price Mid Low Case',
#   'description': 'Oil Price Mid Low Case (70 USD/bbl) is the reference price in the Mid Low Case scenario.\nThe reference price corresponds to the Brent oil price in the base case. Fields in North America will apply a WTI or WCS equivalent based on the expected spread to Brent. Lower oil quality will also reduce field level oil price. \nThe reference price is flat in real terms. It reaches it\'s scenario value (70 USD/bbl) "next year", and is is inflated 2.5% following years.'},
#  {'fieldPath': 'OilLLLC',
#   'description': 'Brent Oil price Low Low Low Case is oil price  at 20 dollar brent price.'},
#  {'fieldPath': 'OilMLLC',
#   'description': 'Brent Oil price Mid Low Low Case is oil price at 50 dollar brent price.'},
#  {'fieldPath': 'OilMMLC',
#   'description': 'Brent Oil price Mid Mid Low Case is oil price at 80 dollar brent price.'},
#  {'fieldPath': 'OilMMLLC',
#   'description': 'Brent Oil price Mid Mid Low Low Case is oil price at 60 dollar brent price.'},
#  {'fieldPath': 'GasLLLC',
#   'description': 'Oil Price Low Low Low Case (20 USD/bbl) is the reference price in the Low Low Low Case scenario.'},
#  {'fieldPath': 'GasMLLC',
#   'description': 'Oil Price Mid Low Low Case (50 USD/bbl) is the reference price in the Low Low Low Case scenario.'},
#  {'fieldPath': 'GasMMLC',
#   'description': 'Oil Price Mid Mid Low Case (80 USD/bbl) is the reference price in the Low Low Low Case scenario.'},
#  {'fieldPath': 'GasMMLLC',
#   'description': 'Oil Price Mid Mid Low Low Case (60 USD/bbl) is the reference price in the Low Low Low Case scenario.'},
#  {'fieldPath': 'CPI',
#   'description': 'Consumer price index shows both the historical and future conversation rate between nominal values and real values.'}]

# %%
# Call the metadata emitter
metadata_emitter = CustomDescriptionsDC(tables_dict={}, env=env, gms_server=gms_server, token=token)

# Create dictionary based on the list column_desc
column_description_dict = {item['fieldPath']: item['description'] for item in column_desc}

# Emit the metadata
metadata_emitter.column_desc_emitter(gms_server=gms_server, token=token, urn=urn, column_dict=column_description_dict)
# Out:
# 2024-02-15 15:09:21,672 - INFO - CustomDescriptionsDC initialized for environment: DEV
# 2024-02-15 15:09:21,674 - INFO - Emitting column descriptions for URN: urn:li:dataset:(urn:li:dataPlatform:mssql,ekofisk.RECubeDataRelease.dbo.vDataFeed_UCube_Prices,DEV)
# 2024-02-15 15:09:21,708 - INFO - Successfully emitted column description metadata.

# %% [markdown]
# ## Case 4 - Abbreviations vol. 3
#
# Finally, we have the Resources table, where we see the following abbreviations:
#
# | MSSQL | XLSX |
# |-------|------|
# | 1P Reserves | 1P Reserves Forward Case |
# | 1P Reserves HC | 1P Reserves High Case |
# | 1P Reserves LC | 1P Reserves Low Case |
# | 1P Reserves MC | 1P Reserves Mid Case |
#
# ... and so on. The same repeats for 2P Reserves, Original Resources and Remaining Resources.
#
# Let's fix it :)

# %%
# Set the environment variables we need

# LOCAL
base_url = config['DATAHUB']['base_url'] # Location of DataHub
gms_server = config['DATAHUB']['gms_server']
token = config['DATAHUB']['token']
env = 'DEV'

# # DEPLOYMENT
# base_url = 'http://10.10.55.28:9002'
# gms_server = 'http://10.10.55.28:8080'
# token = "TOKEN"
# env = 'DEV'

urn = 'urn:li:dataset:(urn:li:dataPlatform:mssql,ekofisk.RECubeDataRelease.dbo.vDataFeed_UCube_Resources,DEV)'

# %%
# Start by getting the entities as before

import requests
from urllib.parse import quote

# Endpoint for GET request
endpoint = f'/openapi/entities/v1/latest?urns={quote(urn)}'

url = f"{gms_server}{endpoint}"

headers = {
    "Authorization": f"Bearer {token}",
    "Content-Type": "application/json"
}

response = requests.get(
    url=url,
    headers=headers
)

response_dict = response.json()

# Column descriptions
column_desc = response_dict['responses'][urn]['aspects']['editableSchemaMetadata']['value']['editableSchemaFieldInfo']
# Column types
column_types = response_dict['responses'][urn]['aspects']['schemaMetadata']['value']['fields']

# %%
# Get existing column names from DataHub
existing_column_names = {item['fieldPath'] for item in column_types}

# %%
def correct_reserves_field_name_v2(field_name):
    # Mapping for the specific keywords to their abbreviations
    keyword_mappings = {
        'Forward': 'F',
        'High': 'H',
        'Low': 'L',
        'Mid': 'M',
        'Case': 'C'  # Change 'Case' to 'C' instead of removing it
    }
    
    # Prefixes to check for in field names
    prefixes = ['1P Reserves', '2P Reserves', 'Original Resources', 'Remaining Resources']
    
    # Find which prefix the field name starts with, if any
    prefix = next((p for p in prefixes if field_name.startswith(p)), None)
    
    if prefix:
        # Remove the prefix from the field name to work with the rest
        suffix = field_name[len(prefix):].strip()
        
        # Split the rest of the field name into parts and apply the mapping
        parts = suffix.split()
        corrected_parts = [keyword_mappings.get(part, '') for part in parts if part in keyword_mappings]
        
        # Rejoin the corrected parts with the prefix, adding a space before the abbreviations if there are any
        corrected_name = prefix + (' ' + ''.join(corrected_parts) if corrected_parts else '')
    else:
        # If the field name doesn't start with any known prefix, return it unchanged
        corrected_name = field_name
    
    return corrected_name

# %%
# Iterate over column_desc and correct the `fieldPath` values if they do not exist in column_types
for field in column_desc:
    if field['fieldPath'] not in existing_column_names:
        corrected_field_path = correct_reserves_field_name_v2(field['fieldPath'])
        # Update fieldPath in column_desc with the corrected name
        field['fieldPath'] = corrected_field_path

# %%
column_desc
# Out:
# [{'fieldPath': 'Id', 'description': 'all tables have Id as Primary Key'},
#  {'fieldPath': 'FK_OilAndGas',
#   'description': 'Links to FK_OilAndGas from other tables'},
#  {'fieldPath': 'FK_Asset',
#   'description': 'Links to FK_Asset from other tables'},
#  {'fieldPath': 'FK_OtherParameter',
#   'description': 'Links to FK_OtherParameter from other tables'},
#  {'fieldPath': 'FK_LifeCycleTS',
#   'description': 'Links to FK_LifeCycleTS from other tables'},
#  {'fieldPath': 'FK_LifeCycle',
#   'description': 'Links to FK_LifeCycle from other tables'},
#  {'fieldPath': 'FK_Company',
#   'description': 'Links to FK_Company from other tables'},
#  {'fieldPath': 'FK_HistoricCompany',
#   'description': 'Links to FK_HistoricCompany from other tables'},
#  {'fieldPath': 'FK_Reserves',
#   'description': 'Links to FK_reserves from other tables'},
#  {'fieldPath': 'FK_OilAndGasType',
#   'description': 'Links to FK_EOilAndGasTypee from other tables'},
#  {'fieldPath': '1P Reserves',
#   'description': '1P Reserve is the proven reserve, is defined as resources with a 90% likelihood and where the assets are either producing or under development. The 1P Reserve value is year dependent, taking into account the life cycle and the probability distribution year by year for each asset._x000D_\nUse the 1P Reserve value for a specific year to see the January 1st remaining reserves for that year. It is important to only select one year, when using the 1P Reserve value item. '},
#  {'fieldPath': '2P Reserves',
#   'description': '2P Reserve is the proven plus probable reserve, is defined as resources with a 50% likelihood and where the assets are either producing or under development. The 2P Reserve value is year dependent, taking into account the life cycle and the probability distribution year by year for each asset._x000D__x000D_\nUse the 2P Reserve value for a specific year to see the January 1st remaining reserves for that year. It is important to only select one year, when using the 1P Reserve value item.'},
#  {'fieldPath': 'Original Resources',
#   'description': 'The Resources value for a specific year is identical to the sum of the future production for the given selection._x000D__x000D_\nUse the Resources value for a specific year to see the January 1st remaining reserves for that year._x000D_\n_x000D_When using Resources with e.g. Discovery Year to see discovery trends, select one Year (typically 1900 to include all resources).'},
#  {'fieldPath': 'Remaining Resources',
#   'description': 'Resources are the remaining economically recoverable volumes. '},
#  {'fieldPath': '1P Reserves FC',
#   'description': '1P Reserve Forward Case is the proven reserves at Forward price deck.'},
#  {'fieldPath': '1P Reserves HC',
#   'description': '1P Reserve High Case is the proven reserves at 120 dollar brent price.'},
#  {'fieldPath': '1P Reserves LC',
#   'description': '1P Reserve Low Case is the proven reserves at 40 dollar brent price.'},
#  {'fieldPath': '1P Reserves MC',
#   'description': '1P Reserve Mid Case is the proven reserves at 100 dollar brent price.'},
#  {'fieldPath': '1P Reserves LLC',
#   'description': '1P Reserve Low Low Case is the proven reserves at 30 dollar brent price.'},
#  {'fieldPath': '1P Reserves MLC',
#   'description': '1P Reserve Mid Low Case is the proven reserves at 70 dollar brent price.'},
#  {'fieldPath': '1P Reserves LLLC',
#   'description': '1P Reserve Low Low Low Case is the proven reserves at 20 dollar brent price.'},
#  {'fieldPath': '1P Reserves MLLC',
#   'description': '1P Reserve Mid Low Low Case is the proven reserves at 50 dollar brent price.'},
#  {'fieldPath': '1P Reserves MMLC',
#   'description': '1P Reserve Mid Mid Low Case is the proven reserves at 80 dollar brent price.'},
#  {'fieldPath': '1P Reserves MMLLC',
#   'description': '1P Reserve Mid Mid Low Low Case is the proven reserves at 60 dollar brent price.'},
#  {'fieldPath': '2P Reserves FC',
#   'description': '2P Reserve Forward Case is the proven plus probable reserves at Forward price deck.'},
#  {'fieldPath': '2P Reserves HC',
#   'description': '2P Reserve High Case is the proven plus probable reserve at 120 dollar brent price.'},
#  {'fieldPath': '2P Reserves LC',
#   'description': '2P Reserve Low Case is the proven plus probable reserve at 40 dollar brent price.'},
#  {'fieldPath': '2P Reserves MC',
#   'description': '2P Reserve Mid Case is the proven plus probable reserve at 100 dollar brent price.'},
#  {'fieldPath': '2P Reserves LLC',
#   'description': '2P Reserve Low Low Case is the proven plus probable reserve at 30 dollar brent price.'},
#  {'fieldPath': '2P Reserves MLC',
#   'description': '2P Reserve Mid Low Case is the proven plus probable reserve at 70 dollar brent price.'},
#  {'fieldPath': '2P Reserves LLLC',
#   'description': '2P Reserve Low Low Low Case is the proven plus probable reserve at 20 dollar brent price.'},
#  {'fieldPath': '2P Reserves MLLC',
#   'description': '2P Reserve Mid Low Low Case is the proven plus probable reserve at 50 dollar brent price.'},
#  {'fieldPath': '2P Reserves MMLC',
#   'description': '2P Reserve Mid Mid Low Case is the proven plus probable reserve at 80 dollar brent price.'},
#  {'fieldPath': '2P Reserves MMLLC',
#   'description': '2P Reserve Mid Mid Low Low Case is the proven plus probable reserve at 60 dollar brent price.'},
#  {'fieldPath': 'Original Resources FC',
#   'description': 'Resources value Forward Case for a specific year is identical to the sum of the future production for the given selection at Forward price deck.'},
#  {'fieldPath': 'Original Resources HC',
#   'description': 'Resources value High Case at 120 dollar brent price.'},
#  {'fieldPath': 'Original Resources LC',
#   'description': 'Resources value Low Case at 40 dollar brent price.'},
#  {'fieldPath': 'Original Resources MC',
#   'description': 'Resources value Mid Case at 100 dollar brent price.'},
#  {'fieldPath': 'Original Resources LLC',
#   'description': 'Resources value Low Low Case at 30 dollar brent price.'},
#  {'fieldPath': 'Original Resources MLC',
#   'description': 'Resources value Mid Low Case at 70 dollar brent price.'},
#  {'fieldPath': 'Original Resources LLLC',
#   'description': 'Resources value Low Low Low Case at 20 dollar brent price.'},
#  {'fieldPath': 'Original Resources MLLC',
#   'description': 'Resources value Mid Low Low Case at 50 dollar brent price.'},
#  {'fieldPath': 'Original Resources MMLC',
#   'description': 'Resources value Mid Mid Low Case at 80 dollar brent price.'},
#  {'fieldPath': 'Original Resources MMLLC',
#   'description': 'Resources value Mid Mid Low Low Case at 60 dollar brent price.'},
#  {'fieldPath': 'Remaining Resources FC',
#   'description': 'Remaining resources Forward Case are the remaining economically recoverable volumes at Forward price deck.'},
#  {'fieldPath': 'Remaining Resources HC',
#   'description': 'Remaining resources High Case at 120 dollar brent price.'},
#  {'fieldPath': 'Remaining Resources LC',
#   'description': 'Remaining resources Low Case at 40 dollar brent price.'},
#  {'fieldPath': 'Remaining Resources MC',
#   'description': 'Remaining resources Mid Case at 100 dollar brent price.'},
#  {'fieldPath': 'Remaining Resources LLC',
#   'description': 'Remaining resources Low Low Case at 30 dollar brent price.'},
#  {'fieldPath': 'Remaining Resources MLC',
#   'description': 'Remaining resources Mid Low Case at 70 dollar brent price.'},
#  {'fieldPath': 'Remaining Resources LLLC',
#   'description': 'Remaining resources Low Low Low Case at 20 dollar brent price.'},
#  {'fieldPath': 'Remaining Resources MLLC',
#   'description': 'Remaining resources Mid Low Low Case at 50 dollar brent price.'},
#  {'fieldPath': 'Remaining Resources MMLC',
#   'description': 'Remaining resources Mid Mid Low Case at 80 dollar brent price.'},
#  {'fieldPath': 'Remaining Resources MMLLC',
#   'description': 'Remaining resources Mid Mid Low Low Case at 60 dollar brent price.'},
#  {'fieldPath': 'FK_WellLifeCycle',
#   'description': 'Links to FK_WellLifeCycle from other tables'}]

# %%
# Call the metadata emitter
metadata_emitter = CustomDescriptionsDC(tables_dict={}, env=env, gms_server=gms_server, token=token)

# Create dictionary based on the list column_desc
column_description_dict = {item['fieldPath']: item['description'] for item in column_desc}

# Emit the metadata
metadata_emitter.column_desc_emitter(gms_server=gms_server, token=token, urn=urn, column_dict=column_description_dict)
# Out:
# 2024-02-15 15:09:50,353 - INFO - CustomDescriptionsDC initialized for environment: DEV
# 2024-02-15 15:09:50,354 - INFO - Emitting column descriptions for URN: urn:li:dataset:(urn:li:dataPlatform:mssql,ekofisk.RECubeDataRelease.dbo.vDataFeed_UCube_Resources,DEV)
# 2024-02-15 15:09:50,389 - INFO - Successfully emitted column description metadata.
